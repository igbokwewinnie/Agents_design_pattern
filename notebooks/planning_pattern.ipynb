# %% [markdown]
# PLANNING PATTERN ReACT Fitness Planner Agent

# %%
import sys
sys.path.append("../src")

# %%
#define tools
import re
from agentic_patterns.tool_pattern.tool import tool

@tool
def choose_exercises(workout_type: str) -> list:
    """Choose exercises for a given workout type."""
    if workout_type == "cardio":
        return ["running", "cycling", "jump rope"]
    elif workout_type == "strength":
        return ["push-ups", "squats", "deadlifts"]
    elif workout_type == "flexibility":
        return ["yoga", "stretching", "pilates"]
    return []

@tool
def plan_reps(exercises: list) -> dict:
    """Plan repetitions or duration for each exercise."""
    plan = {}
    for ex in exercises:
        if ex in ["running", "cycling"]:
            plan[ex] = "30 minutes"
        elif ex in ["jump rope", "push-ups", "squats", "deadlifts"]:
            plan[ex] = "3 sets of 12 reps"
        elif ex in ["yoga", "stretching", "pilates"]:
            plan[ex] = "20 minutes"
    return plan

@tool
def calculate_total_calories(exercise_plan: dict) -> int:
    """Estimate total calories burned from the exercise plan."""
    calories = 0
    for ex, reps in exercise_plan.items():
        numbers = list(map(int, re.findall(r'\d+', reps)))  # extract all numbers
        if "minutes" in reps:
            calories += numbers[0] * 10  # 10 calories per minute
        elif "sets" in reps:
            calories += numbers[0] * numbers[1] * 5  # sets * reps * 5 calories
    return calories

# %%
#initialize our agent
from agentic_patterns.planning_pattern.react_agent import ReactAgent

# Create the agent with the tools
agent = ReactAgent(tools=[choose_exercises, plan_reps, calculate_total_calories])

# %%
user_msg = "Plan a 3-day workout routine with cardio, strength, and flexibility exercises."

response = agent.run(user_msg=user_msg)

print(response)
# Out:
# Thought: To plan a 3-day workout routine, I need to choose exercises for each day, considering cardio, strength, and flexibility exercises. Then, I can plan the repetitions or duration for each exercise and estimate the total calories burned.
#
# Using Tool: choose_exercises
#
# Tool call dict:
# {'name': 'choose_exercises', 'arguments': {'workout_type': 'cardio'}, 'id': 0}
#
# Tool result:
# ['running', 'cycling', 'jump rope']
#
# Using Tool: choose_exercises
#
# Tool call dict:
# {'name': 'choose_exercises', 'arguments': {'workout_type': 'strength'}, 'id': 1}
#
# Tool result:
# ['push-ups', 'squats', 'deadlifts']
#
# Using Tool: choose_exercises
#
# Tool call dict:
# {'name': 'choose_exercises', 'arguments': {'workout_type': 'flexibility'}, 'id': 2}
#
# Tool result:
# ['yoga', 'stretching', 'pilates']
#
# Observations: {0: ['running', 'cycling', 'jump rope'], 1: ['push-ups', 'squats', 'deadlifts'], 2: ['yoga', 'stretching', 'pilates']}
#
# Thought: I have the list of exercises for each type. Now, I need to plan the repetitions or duration for each exercise.
#
# Using Tool: plan_reps
#
# Tool call dict:
# {'name': 'plan_reps', 'arguments': {'exercises': ['running', 'cycling', 'jump rope', 'push-ups', 'squats', 'deadlifts', 'yoga', 'stretching', 'pilates']}, 'id': 3}
#
# Tool result:
# {'running': '30 minutes', 'cycling': '30 minutes', 'jump rope': '3 sets of 12 reps', 'push-ups': '3 sets of 12 reps', 'squats': '3 sets of 12 reps', 'deadlifts': '3 sets of 12 reps', 'yoga': '20 minutes', 'stretching': '20 minutes', 'pilates': '20 minutes'}
#
# Observations: {3: {'running': '30 minutes', 'cycling': '30 minutes', 'jump rope': '3 sets of 12 reps', 'push-ups': '3 sets of 12 reps', 'squats': '3 sets of 12 reps', 'deadlifts': '3 sets of 12 reps', 'yoga': '20 minutes', 'stretching': '20 minutes', 'pilates': '20 minutes'}}
#
# Thought: I have the planned repetitions or duration for each exercise. Now, I need to estimate the total calories burned from the exercise plan.
#
# Using Tool: calculate_total_calories
#
# Tool call dict:
# {'name': 'calculate_total_calories', 'arguments': {'exercise_plan': {'running': '30 minutes', 'cycling': '30 minutes', 'jump rope': '3 sets of 12 reps', 'push-ups': '3 sets of 12 reps', 'squats': '3 sets of 12 reps', 'deadlifts': '3 sets of 12 reps', 'yoga': '20 minutes', 'stretching': '20 minutes', 'pilates': '20 minutes'}}, 'id': 4}
#
# Tool result:
# 1920
#
# Observations: {4: 1920}
# Here is a 3-day workout routine with cardio, strength, and flexibility exercises:
# Day 1: Cardio (running for 30 minutes, cycling for 30 minutes) and flexibility (yoga for 20 minutes, stretching for 20 minutes)
# Day 2: Strength (push-ups for 3 sets of 12 reps, squats for 3 sets of 12 reps, deadlifts for 3 sets of 12 reps) and flexibility (pilates for 20 minutes)
# Day 3: Cardio (jump rope for 3 sets of 12 reps) and flexibility (yoga for 20 minutes, stretching for 20 minutes)
# This workout routine is estimated to burn approximately 1920 calories.
